# %%
# !python -c 'import tensorflow as tf; print(tf.__version__)'
# Out:
# 1.15.0

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.6/dist-packages (2.1.1)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from transformers) (1.10.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers) (1.17.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers) (2.21.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.6/dist-packages (from transformers) (0.1.83)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.6/dist-packages (from transformers) (0.0.35)
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from transformers) (2019.11.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from transformers) (4.28.1)
# Requirement already satisfied: botocore<1.14.0,>=1.13.4 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers) (1.13.4)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers) (0.2.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers) (0.9.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2019.9.11)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.12.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (7.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (0.14.0)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.14.0,>=1.13.4->boto3->transformers) (0.15.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1; python_version >= "2.7" in /usr/local/lib/python3.6/dist-packages (from botocore<1.14.0,>=1.13.4->boto3->transformers) (2.6.1)

# %%
import torch

# %%
from transformers import GPT2Tokenizer, GPT2DoubleHeadsModel

tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2DoubleHeadsModel.from_pretrained('gpt2')

# Add a [CLS] to the vocabulary (we should train it also!)
tokenizer.add_special_tokens({'cls_token': '[CLS]'})
model.resize_token_embeddings(len(tokenizer))  # Update the model embeddings with the new vocabulary size
print(tokenizer.cls_token_id, len(tokenizer))  # The newly token the last token of the vocabulary

choices = ["Hello, my dog is cute [CLS]", "Hello, my cat is cute [CLS]"]
encoded_choices = [tokenizer.encode(s) for s in choices]
cls_token_location = [tokens.index(tokenizer.cls_token_id) for tokens in encoded_choices]

input_ids = torch.tensor(encoded_choices).unsqueeze(0)  # Batch size: 1, number of choices: 2
mc_token_ids = torch.tensor([cls_token_location])  # Batch size: 1

outputs = model(input_ids, mc_token_ids=mc_token_ids)
lm_prediction_scores, mc_prediction_scores = outputs[:2]
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# 50257 50258

# %%
import transformers

# %%
dir(transformers)
# Out:
# ['AdamW',
#  'AutoConfig',
#  'AutoModel',
#  'AutoModelForQuestionAnswering',
#  'AutoModelForSequenceClassification',
#  'AutoModelWithLMHead',
#  'AutoTokenizer',
#  'BERT_PRETRAINED_CONFIG_ARCHIVE_MAP',
#  'BERT_PRETRAINED_MODEL_ARCHIVE_MAP',
#  'BasicTokenizer',
#  'BertConfig',
#  'BertForMaskedLM',
#  'BertForMultipleChoice',
#  'BertForNextSentencePrediction',
#  'BertForPreTraining',
#  'BertForQuestionAnswering',
#  'BertForSequenceClassification',
#  'BertForTokenClassification',
#  'BertModel',
#  'BertPreTrainedModel',
#  'BertTokenizer',
#  'CONFIG_NAME',
#  'CTRLConfig',
#  'CTRLLMHeadModel',
#  'CTRLModel',
#  'CTRLPreTrainedModel',
#  'CTRLTokenizer',
#  'CTRL_PRETRAINED_CONFIG_ARCHIVE_MAP',
#  'CTRL_PRETRAINED_MODEL_ARCHIVE_MAP',
#  'ConstantLRSchedule',
#  'Conv1D',
#  'DISTILBERT_PRETRAINED_CONFIG_ARCHIVE_MAP',
#  'DISTILBERT_PRETRAINED_MODEL_ARCHIVE_MAP',
#  'DataProcessor',
#  'DistilBertConfig',
#  'DistilBertForMaskedLM',
#  'DistilBertForQuestionAnswering',
#  'DistilBertForSequenceClassification',
#  'DistilBertModel',
#  'DistilBertTokenizer',
#  'GPT2Config',
#  'GPT2DoubleHeadsModel',
#  'GPT2LMHeadModel',
#  'GPT2Model',
#  'GPT2PreTrainedModel',
#  'GPT2Tokenizer',
#  'GPT2_PRETRAINED_CONFIG_ARCHIVE_MAP',
#  'GPT2_PRETRAINED_MODEL_ARCHIVE_MAP',
#  'InputExample',
#  'InputFeatures',
#  'OPENAI_GPT_PRETRAINED_CONFIG_ARCHIVE_MAP',
#  'OPENAI_GPT_PRETRAINED_MODEL_ARCHIVE_MAP',
#  'OpenAIGPTConfig',
#  'OpenAIGPTDoubleHeadsModel',
#  'OpenAIGPTLMHeadModel',
#  'OpenAIGPTModel',
#  'OpenAIGPTPreTrainedModel',
#  'OpenAIGPTTokenizer',
#  'PYTORCH_PRETRAINED_BERT_CACHE',
#  'PYTORCH_TRANSFORMERS_CACHE',
#  'PreTrainedModel',
#  'PreTrainedTokenizer',
#  'PretrainedConfig',
#  'ROBERTA_PRETRAINED_CONFIG_ARCHIVE_MAP',
#  'ROBERTA_PRETRAINED_MODEL_ARCHIVE_MAP',
#  'RobertaConfig',
#  'RobertaForMaskedLM',
#  'RobertaForMultipleChoice',
#  'RobertaForSequenceClassification',
#  'RobertaModel',
#  'RobertaTokenizer',
#  'SPIECE_UNDERLINE',
#  'TF2_WEIGHTS_NAME',
#  'TF_WEIGHTS_NAME',
#  'TRANSFORMERS_CACHE',
#  'TRANSFO_XL_PRETRAINED_CONFIG_ARCHIVE_MAP',
#  'TRANSFO_XL_PRETRAINED_MODEL_ARCHIVE_MAP',
#  'TransfoXLConfig',
#  'TransfoXLCorpus',
#  'TransfoXLLMHeadModel',
#  'TransfoXLModel',
#  'TransfoXLPreTrainedModel',
#  'TransfoXLTokenizer',
#  'WEIGHTS_NAME',
#  'WarmupConstantSchedule',
#  'WarmupCosineSchedule',
#  'WarmupCosineWithHardRestartsSchedule',
#  'WarmupLinearSchedule',
#  'WordpieceTokenizer',
#  'XLMConfig',
#  'XLMForQuestionAnswering',
#  'XLMForQuestionAnsweringSimple',
#  'XLMForSequenceClassification',
#  'XLMModel',
#  'XLMPreTrainedModel',
#  'XLMTokenizer',
#  'XLMWithLMHeadModel',
#  'XLM_PRETRAINED_CONFIG_ARCHIVE_MAP',
#  'XLM_PRETRAINED_MODEL_ARCHIVE_MAP',
#  'XLNET_PRETRAINED_CONFIG_ARCHIVE_MAP',
#  'XLNET_PRETRAINED_MODEL_ARCHIVE_MAP',
#  'XLNetConfig',
#  'XLNetForMultipleChoice',
#  'XLNetForQuestionAnswering',
#  'XLNetForQuestionAnsweringSimple',
#  'XLNetForSequenceClassification',
#  'XLNetLMHeadModel',
#  'XLNetModel',
#  'XLNetPreTrainedModel',
#  'XLNetTokenizer',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'absl',
#  'add_end_docstrings',
#  'add_start_docstrings',
#  'cached_path',
#  'configuration_auto',
#  'configuration_bert',
#  'configuration_ctrl',
#  'configuration_distilbert',
#  'configuration_gpt2',
#  'configuration_openai',
#  'configuration_roberta',
#  'configuration_transfo_xl',
#  'configuration_utils',
#  'configuration_xlm',
#  'configuration_xlnet',
#  'convert_tf_weight_name_to_pt_weight_name',
#  'data',
#  'file_utils',
#  'glue_compute_metrics',
#  'glue_convert_examples_to_features',
#  'glue_output_modes',
#  'glue_processors',
#  'glue_tasks_num_labels',
#  'is_sklearn_available',
#  'is_tf_available',
#  'is_torch_available',
#  'load_pytorch_checkpoint_in_tf2_model',
#  'load_pytorch_model_in_tf2_model',
#  'load_pytorch_weights_in_tf2_model',
#  'load_tf2_checkpoint_in_pytorch_model',
#  'load_tf2_model_in_pytorch_model',
#  'load_tf2_weights_in_pytorch_model',
#  'load_tf_weights_in_bert',
#  'load_tf_weights_in_gpt2',
#  'load_tf_weights_in_openai_gpt',
#  'load_tf_weights_in_transfo_xl',
#  'load_tf_weights_in_xlnet',
#  'logger',
#  'logging',
#  'modeling_auto',
#  'modeling_bert',
#  'modeling_ctrl',
#  'modeling_distilbert',
#  'modeling_gpt2',
#  'modeling_openai',
#  'modeling_roberta',
#  'modeling_tf_pytorch_utils',
#  'modeling_transfo_xl',
#  'modeling_transfo_xl_utilities',
#  'modeling_utils',
#  'modeling_xlm',
#  'modeling_xlnet',
#  'optimization',
#  'prune_layer',
#  'tokenization_auto',
#  'tokenization_bert',
#  'tokenization_ctrl',
#  'tokenization_distilbert',
#  'tokenization_gpt2',
#  'tokenization_openai',
#  'tokenization_roberta',
#  'tokenization_transfo_xl',
#  'tokenization_utils',
#  'tokenization_xlm',
#  'tokenization_xlnet']

# %%
# %ls
# Out:
# sample_data/  transformator/

# %%
cd data
# Out:
# [Errno 2] No such file or directory: 'data'
# /content

# %%
ls
# Out:
# sample_data/  transformator/

# %%
from transformers import GPT2Tokenizer, GPT2DoubleHeadsModel

tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2DoubleHeadsModel.from_pretrained('gpt2')

# Add a [CLS] to the vocabulary (we should train it also!)
tokenizer.add_special_tokens({'cls_token': '[CLS]'})
model.resize_token_embeddings(len(tokenizer))  # Update the model embeddings with the new vocabulary size
print(tokenizer.cls_token_id, len(tokenizer))  # The newly token the last token of the vocabulary

choices = ["Hello, my dog is cute [CLS]", "Hello, my cat is cute [CLS]"]
encoded_choices = [tokenizer.encode(s) for s in choices]
cls_token_location = [tokens.index(tokenizer.cls_token_id) for tokens in encoded_choices]

input_ids = torch.tensor(encoded_choices).unsqueeze(0)  # Batch size: 1, number of choices: 2
mc_token_ids = torch.tensor([cls_token_location])  # Batch size: 1

outputs = model(input_ids, mc_token_ids=mc_token_ids)
lm_prediction_scores, mc_prediction_scores = outputs[:2]
# Out:
# 50257 50258

# %%
model.eval()
# Out:
# GPT2DoubleHeadsModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50258, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (2): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (3): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (4): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (5): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (6): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (7): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (8): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (9): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (10): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (11): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
#   (multiple_choice_head): SequenceSummary(
#     (summary): Linear(in_features=768, out_features=1, bias=True)
#     (activation): Identity()
#     (first_dropout): Dropout(p=0.1, inplace=False)
#     (last_dropout): Identity()
#   )
# )

# %%
for idx, m in enumerate(model.modules()):
        print(idx, '->', m)
# Out:
# 0 -> GPT2DoubleHeadsModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50258, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (2): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (3): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (4): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (5): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (6): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (7): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (8): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (9): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (10): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (11): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
#   (multiple_choice_head): SequenceSummary(
#     (summary): Linear(in_features=768, out_features=1, bias=True)
#     (activation): Identity()
#     (first_dropout): Dropout(p=0.1, inplace=False)
#     (last_dropout): Identity()
#   )
# )
# 1 -> GPT2Model(
#   (wte): Embedding(50258, 768)
#   (wpe): Embedding(1024, 768)
#   (drop): Dropout(p=0.1, inplace=False)
#   (h): ModuleList(
#     (0): Block(
#       (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (c_attn): Conv1D()
#         (c_proj): Conv1D()
#         (attn_dropout): Dropout(p=0.1, inplace=False)
#         (resid_dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (c_fc): Conv1D()
#         (c_proj): Conv1D()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (1): Block(
#       (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (c_attn): Conv1D()
#         (c_proj): Conv1D()
#         (attn_dropout): Dropout(p=0.1, inplace=False)
#         (resid_dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (c_fc): Conv1D()
#         (c_proj): Conv1D()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (2): Block(
#       (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (c_attn): Conv1D()
#         (c_proj): Conv1D()
#         (attn_dropout): Dropout(p=0.1, inplace=False)
#         (resid_dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (c_fc): Conv1D()
#         (c_proj): Conv1D()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (3): Block(
#       (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (c_attn): Conv1D()
#         (c_proj): Conv1D()
#         (attn_dropout): Dropout(p=0.1, inplace=False)
#         (resid_dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (c_fc): Conv1D()
#         (c_proj): Conv1D()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (4): Block(
#       (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (c_attn): Conv1D()
#         (c_proj): Conv1D()
#         (attn_dropout): Dropout(p=0.1, inplace=False)
#         (resid_dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (c_fc): Conv1D()
#         (c_proj): Conv1D()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (5): Block(
#       (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (c_attn): Conv1D()
#         (c_proj): Conv1D()
#         (attn_dropout): Dropout(p=0.1, inplace=False)
#         (resid_dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (c_fc): Conv1D()
#         (c_proj): Conv1D()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (6): Block(
#       (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (c_attn): Conv1D()
#         (c_proj): Conv1D()
#         (attn_dropout): Dropout(p=0.1, inplace=False)
#         (resid_dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (c_fc): Conv1D()
#         (c_proj): Conv1D()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (7): Block(
#       (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (c_attn): Conv1D()
#         (c_proj): Conv1D()
#         (attn_dropout): Dropout(p=0.1, inplace=False)
#         (resid_dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (c_fc): Conv1D()
#         (c_proj): Conv1D()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (8): Block(
#       (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (c_attn): Conv1D()
#         (c_proj): Conv1D()
#         (attn_dropout): Dropout(p=0.1, inplace=False)
#         (resid_dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (c_fc): Conv1D()
#         (c_proj): Conv1D()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (9): Block(
#       (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (c_attn): Conv1D()
#         (c_proj): Conv1D()
#         (attn_dropout): Dropout(p=0.1, inplace=False)
#         (resid_dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (c_fc): Conv1D()
#         (c_proj): Conv1D()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (10): Block(
#       (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (c_attn): Conv1D()
#         (c_proj): Conv1D()
#         (attn_dropout): Dropout(p=0.1, inplace=False)
#         (resid_dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (c_fc): Conv1D()
#         (c_proj): Conv1D()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (11): Block(
#       (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (c_attn): Conv1D()
#         (c_proj): Conv1D()
#         (attn_dropout): Dropout(p=0.1, inplace=False)
#         (resid_dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (c_fc): Conv1D()
#         (c_proj): Conv1D()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# )
# 2 -> Embedding(50258, 768)
# 3 -> Embedding(1024, 768)
# 4 -> Dropout(p=0.1, inplace=False)
# 5 -> ModuleList(
#   (0): Block(
#     (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (attn): Attention(
#       (c_attn): Conv1D()
#       (c_proj): Conv1D()
#       (attn_dropout): Dropout(p=0.1, inplace=False)
#       (resid_dropout): Dropout(p=0.1, inplace=False)
#     )
#     (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (mlp): MLP(
#       (c_fc): Conv1D()
#       (c_proj): Conv1D()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (1): Block(
#     (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (attn): Attention(
#       (c_attn): Conv1D()
#       (c_proj): Conv1D()
#       (attn_dropout): Dropout(p=0.1, inplace=False)
#       (resid_dropout): Dropout(p=0.1, inplace=False)
#     )
#     (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (mlp): MLP(
#       (c_fc): Conv1D()
#       (c_proj): Conv1D()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (2): Block(
#     (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (attn): Attention(
#       (c_attn): Conv1D()
#       (c_proj): Conv1D()
#       (attn_dropout): Dropout(p=0.1, inplace=False)
#       (resid_dropout): Dropout(p=0.1, inplace=False)
#     )
#     (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (mlp): MLP(
#       (c_fc): Conv1D()
#       (c_proj): Conv1D()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (3): Block(
#     (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (attn): Attention(
#       (c_attn): Conv1D()
#       (c_proj): Conv1D()
#       (attn_dropout): Dropout(p=0.1, inplace=False)
#       (resid_dropout): Dropout(p=0.1, inplace=False)
#     )
#     (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (mlp): MLP(
#       (c_fc): Conv1D()
#       (c_proj): Conv1D()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (4): Block(
#     (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (attn): Attention(
#       (c_attn): Conv1D()
#       (c_proj): Conv1D()
#       (attn_dropout): Dropout(p=0.1, inplace=False)
#       (resid_dropout): Dropout(p=0.1, inplace=False)
#     )
#     (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (mlp): MLP(
#       (c_fc): Conv1D()
#       (c_proj): Conv1D()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (5): Block(
#     (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (attn): Attention(
#       (c_attn): Conv1D()
#       (c_proj): Conv1D()
#       (attn_dropout): Dropout(p=0.1, inplace=False)
#       (resid_dropout): Dropout(p=0.1, inplace=False)
#     )
#     (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (mlp): MLP(
#       (c_fc): Conv1D()
#       (c_proj): Conv1D()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (6): Block(
#     (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (attn): Attention(
#       (c_attn): Conv1D()
#       (c_proj): Conv1D()
#       (attn_dropout): Dropout(p=0.1, inplace=False)
#       (resid_dropout): Dropout(p=0.1, inplace=False)
#     )
#     (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (mlp): MLP(
#       (c_fc): Conv1D()
#       (c_proj): Conv1D()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (7): Block(
#     (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (attn): Attention(
#       (c_attn): Conv1D()
#       (c_proj): Conv1D()
#       (attn_dropout): Dropout(p=0.1, inplace=False)
#       (resid_dropout): Dropout(p=0.1, inplace=False)
#     )
#     (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (mlp): MLP(
#       (c_fc): Conv1D()
#       (c_proj): Conv1D()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (8): Block(
#     (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (attn): Attention(
#       (c_attn): Conv1D()
#       (c_proj): Conv1D()
#       (attn_dropout): Dropout(p=0.1, inplace=False)
#       (resid_dropout): Dropout(p=0.1, inplace=False)
#     )
#     (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (mlp): MLP(
#       (c_fc): Conv1D()
#       (c_proj): Conv1D()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (9): Block(
#     (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (attn): Attention(
#       (c_attn): Conv1D()
#       (c_proj): Conv1D()
#       (attn_dropout): Dropout(p=0.1, inplace=False)
#       (resid_dropout): Dropout(p=0.1, inplace=False)
#     )
#     (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (mlp): MLP(
#       (c_fc): Conv1D()
#       (c_proj): Conv1D()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (10): Block(
#     (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (attn): Attention(
#       (c_attn): Conv1D()
#       (c_proj): Conv1D()
#       (attn_dropout): Dropout(p=0.1, inplace=False)
#       (resid_dropout): Dropout(p=0.1, inplace=False)
#     )
#     (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (mlp): MLP(
#       (c_fc): Conv1D()
#       (c_proj): Conv1D()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (11): Block(
#     (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (attn): Attention(
#       (c_attn): Conv1D()
#       (c_proj): Conv1D()
#       (attn_dropout): Dropout(p=0.1, inplace=False)
#       (resid_dropout): Dropout(p=0.1, inplace=False)
#     )
#     (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (mlp): MLP(
#       (c_fc): Conv1D()
#       (c_proj): Conv1D()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
# )
# 6 -> Block(
#   (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (attn): Attention(
#     (c_attn): Conv1D()
#     (c_proj): Conv1D()
#     (attn_dropout): Dropout(p=0.1, inplace=False)
#     (resid_dropout): Dropout(p=0.1, inplace=False)
#   )
#   (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (mlp): MLP(
#     (c_fc): Conv1D()
#     (c_proj): Conv1D()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )
# 7 -> LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# 8 -> Attention(
#   (c_attn): Conv1D()
#   (c_proj): Conv1D()
#   (attn_dropout): Dropout(p=0.1, inplace=False)
#   (resid_dropout): Dropout(p=0.1, inplace=False)
# )
# 9 -> Conv1D()
# 10 -> Conv1D()
# 11 -> Dropout(p=0.1, inplace=False)
# 12 -> Dropout(p=0.1, inplace=False)
# 13 -> LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# 14 -> MLP(
#   (c_fc): Conv1D()
#   (c_proj): Conv1D()
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# 15 -> Conv1D()
# 16 -> Conv1D()
# 17 -> Dropout(p=0.1, inplace=False)
# 18 -> Block(
#   (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (attn): Attention(
#     (c_attn): Conv1D()
#     (c_proj): Conv1D()
#     (attn_dropout): Dropout(p=0.1, inplace=False)
#     (resid_dropout): Dropout(p=0.1, inplace=False)
#   )
#   (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (mlp): MLP(
#     (c_fc): Conv1D()
#     (c_proj): Conv1D()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )
# 19 -> LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# 20 -> Attention(
#   (c_attn): Conv1D()
#   (c_proj): Conv1D()
#   (attn_dropout): Dropout(p=0.1, inplace=False)
#   (resid_dropout): Dropout(p=0.1, inplace=False)
# )
# 21 -> Conv1D()
# 22 -> Conv1D()
# 23 -> Dropout(p=0.1, inplace=False)
# 24 -> Dropout(p=0.1, inplace=False)
# 25 -> LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# 26 -> MLP(
#   (c_fc): Conv1D()
#   (c_proj): Conv1D()
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# 27 -> Conv1D()
# 28 -> Conv1D()
# 29 -> Dropout(p=0.1, inplace=False)
# 30 -> Block(
#   (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (attn): Attention(
#     (c_attn): Conv1D()
#     (c_proj): Conv1D()
#     (attn_dropout): Dropout(p=0.1, inplace=False)
#     (resid_dropout): Dropout(p=0.1, inplace=False)
#   )
#   (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (mlp): MLP(
#     (c_fc): Conv1D()
#     (c_proj): Conv1D()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )
# 31 -> LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# 32 -> Attention(
#   (c_attn): Conv1D()
#   (c_proj): Conv1D()
#   (attn_dropout): Dropout(p=0.1, inplace=False)
#   (resid_dropout): Dropout(p=0.1, inplace=False)
# )
# 33 -> Conv1D()
# 34 -> Conv1D()
# 35 -> Dropout(p=0.1, inplace=False)
# 36 -> Dropout(p=0.1, inplace=False)
# 37 -> LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# 38 -> MLP(
#   (c_fc): Conv1D()
#   (c_proj): Conv1D()
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# 39 -> Conv1D()
# 40 -> Conv1D()
# 41 -> Dropout(p=0.1, inplace=False)
# 42 -> Block(
#   (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (attn): Attention(
#     (c_attn): Conv1D()
#     (c_proj): Conv1D()
#     (attn_dropout): Dropout(p=0.1, inplace=False)
#     (resid_dropout): Dropout(p=0.1, inplace=False)
#   )
#   (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (mlp): MLP(
#     (c_fc): Conv1D()
#     (c_proj): Conv1D()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )
# 43 -> LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# 44 -> Attention(
#   (c_attn): Conv1D()
#   (c_proj): Conv1D()
#   (attn_dropout): Dropout(p=0.1, inplace=False)
#   (resid_dropout): Dropout(p=0.1, inplace=False)
# )
# 45 -> Conv1D()
# 46 -> Conv1D()
# 47 -> Dropout(p=0.1, inplace=False)
# 48 -> Dropout(p=0.1, inplace=False)
# 49 -> LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# 50 -> MLP(
#   (c_fc): Conv1D()
#   (c_proj): Conv1D()
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# 51 -> Conv1D()
# 52 -> Conv1D()
# 53 -> Dropout(p=0.1, inplace=False)
# 54 -> Block(
#   (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (attn): Attention(
#     (c_attn): Conv1D()
#     (c_proj): Conv1D()
#     (attn_dropout): Dropout(p=0.1, inplace=False)
#     (resid_dropout): Dropout(p=0.1, inplace=False)
#   )
#   (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (mlp): MLP(
#     (c_fc): Conv1D()
#     (c_proj): Conv1D()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )
# 55 -> LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# 56 -> Attention(
#   (c_attn): Conv1D()
#   (c_proj): Conv1D()
#   (attn_dropout): Dropout(p=0.1, inplace=False)
#   (resid_dropout): Dropout(p=0.1, inplace=False)
# )
# 57 -> Conv1D()
# 58 -> Conv1D()
# 59 -> Dropout(p=0.1, inplace=False)
# 60 -> Dropout(p=0.1, inplace=False)
# 61 -> LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# 62 -> MLP(
#   (c_fc): Conv1D()
#   (c_proj): Conv1D()
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# 63 -> Conv1D()
# 64 -> Conv1D()
# 65 -> Dropout(p=0.1, inplace=False)
# 66 -> Block(
#   (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (attn): Attention(
#     (c_attn): Conv1D()
#     (c_proj): Conv1D()
#     (attn_dropout): Dropout(p=0.1, inplace=False)
#     (resid_dropout): Dropout(p=0.1, inplace=False)
#   )
#   (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (mlp): MLP(
#     (c_fc): Conv1D()
#     (c_proj): Conv1D()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )
# 67 -> LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# 68 -> Attention(
#   (c_attn): Conv1D()
#   (c_proj): Conv1D()
#   (attn_dropout): Dropout(p=0.1, inplace=False)
#   (resid_dropout): Dropout(p=0.1, inplace=False)
# )
# 69 -> Conv1D()
# 70 -> Conv1D()
# 71 -> Dropout(p=0.1, inplace=False)
# 72 -> Dropout(p=0.1, inplace=False)
# 73 -> LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# 74 -> MLP(
#   (c_fc): Conv1D()
#   (c_proj): Conv1D()
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# 75 -> Conv1D()
# 76 -> Conv1D()
# 77 -> Dropout(p=0.1, inplace=False)
# 78 -> Block(
#   (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (attn): Attention(
#     (c_attn): Conv1D()
#     (c_proj): Conv1D()
#     (attn_dropout): Dropout(p=0.1, inplace=False)
#     (resid_dropout): Dropout(p=0.1, inplace=False)
#   )
#   (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (mlp): MLP(
#     (c_fc): Conv1D()
#     (c_proj): Conv1D()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )
# 79 -> LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# 80 -> Attention(
#   (c_attn): Conv1D()
#   (c_proj): Conv1D()
#   (attn_dropout): Dropout(p=0.1, inplace=False)
#   (resid_dropout): Dropout(p=0.1, inplace=False)
# )
# 81 -> Conv1D()
# 82 -> Conv1D()
# 83 -> Dropout(p=0.1, inplace=False)
# 84 -> Dropout(p=0.1, inplace=False)
# 85 -> LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# 86 -> MLP(
#   (c_fc): Conv1D()
#   (c_proj): Conv1D()
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# 87 -> Conv1D()
# 88 -> Conv1D()
# 89 -> Dropout(p=0.1, inplace=False)
# 90 -> Block(
#   (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (attn): Attention(
#     (c_attn): Conv1D()
#     (c_proj): Conv1D()
#     (attn_dropout): Dropout(p=0.1, inplace=False)
#     (resid_dropout): Dropout(p=0.1, inplace=False)
#   )
#   (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (mlp): MLP(
#     (c_fc): Conv1D()
#     (c_proj): Conv1D()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )
# 91 -> LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# 92 -> Attention(
#   (c_attn): Conv1D()
#   (c_proj): Conv1D()
#   (attn_dropout): Dropout(p=0.1, inplace=False)
#   (resid_dropout): Dropout(p=0.1, inplace=False)
# )
# 93 -> Conv1D()
# 94 -> Conv1D()
# 95 -> Dropout(p=0.1, inplace=False)
# 96 -> Dropout(p=0.1, inplace=False)
# 97 -> LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# 98 -> MLP(
#   (c_fc): Conv1D()
#   (c_proj): Conv1D()
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# 99 -> Conv1D()
# 100 -> Conv1D()
# 101 -> Dropout(p=0.1, inplace=False)
# 102 -> Block(
#   (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (attn): Attention(
#     (c_attn): Conv1D()
#     (c_proj): Conv1D()
#     (attn_dropout): Dropout(p=0.1, inplace=False)
#     (resid_dropout): Dropout(p=0.1, inplace=False)
#   )
#   (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (mlp): MLP(
#     (c_fc): Conv1D()
#     (c_proj): Conv1D()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )
# 103 -> LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# 104 -> Attention(
#   (c_attn): Conv1D()
#   (c_proj): Conv1D()
#   (attn_dropout): Dropout(p=0.1, inplace=False)
#   (resid_dropout): Dropout(p=0.1, inplace=False)
# )
# 105 -> Conv1D()
# 106 -> Conv1D()
# 107 -> Dropout(p=0.1, inplace=False)
# 108 -> Dropout(p=0.1, inplace=False)
# 109 -> LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# 110 -> MLP(
#   (c_fc): Conv1D()
#   (c_proj): Conv1D()
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# 111 -> Conv1D()
# 112 -> Conv1D()
# 113 -> Dropout(p=0.1, inplace=False)
# 114 -> Block(
#   (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (attn): Attention(
#     (c_attn): Conv1D()
#     (c_proj): Conv1D()
#     (attn_dropout): Dropout(p=0.1, inplace=False)
#     (resid_dropout): Dropout(p=0.1, inplace=False)
#   )
#   (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (mlp): MLP(
#     (c_fc): Conv1D()
#     (c_proj): Conv1D()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )
# 115 -> LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# 116 -> Attention(
#   (c_attn): Conv1D()
#   (c_proj): Conv1D()
#   (attn_dropout): Dropout(p=0.1, inplace=False)
#   (resid_dropout): Dropout(p=0.1, inplace=False)
# )
# 117 -> Conv1D()
# 118 -> Conv1D()
# 119 -> Dropout(p=0.1, inplace=False)
# 120 -> Dropout(p=0.1, inplace=False)
# 121 -> LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# 122 -> MLP(
#   (c_fc): Conv1D()
#   (c_proj): Conv1D()
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# 123 -> Conv1D()
# 124 -> Conv1D()
# 125 -> Dropout(p=0.1, inplace=False)
# 126 -> Block(
#   (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (attn): Attention(
#     (c_attn): Conv1D()
#     (c_proj): Conv1D()
#     (attn_dropout): Dropout(p=0.1, inplace=False)
#     (resid_dropout): Dropout(p=0.1, inplace=False)
#   )
#   (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (mlp): MLP(
#     (c_fc): Conv1D()
#     (c_proj): Conv1D()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )
# 127 -> LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# 128 -> Attention(
#   (c_attn): Conv1D()
#   (c_proj): Conv1D()
#   (attn_dropout): Dropout(p=0.1, inplace=False)
#   (resid_dropout): Dropout(p=0.1, inplace=False)
# )
# 129 -> Conv1D()
# 130 -> Conv1D()
# 131 -> Dropout(p=0.1, inplace=False)
# 132 -> Dropout(p=0.1, inplace=False)
# 133 -> LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# 134 -> MLP(
#   (c_fc): Conv1D()
#   (c_proj): Conv1D()
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# 135 -> Conv1D()
# 136 -> Conv1D()
# 137 -> Dropout(p=0.1, inplace=False)
# 138 -> Block(
#   (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (attn): Attention(
#     (c_attn): Conv1D()
#     (c_proj): Conv1D()
#     (attn_dropout): Dropout(p=0.1, inplace=False)
#     (resid_dropout): Dropout(p=0.1, inplace=False)
#   )
#   (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (mlp): MLP(
#     (c_fc): Conv1D()
#     (c_proj): Conv1D()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )
# 139 -> LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# 140 -> Attention(
#   (c_attn): Conv1D()
#   (c_proj): Conv1D()
#   (attn_dropout): Dropout(p=0.1, inplace=False)
#   (resid_dropout): Dropout(p=0.1, inplace=False)
# )
# 141 -> Conv1D()
# 142 -> Conv1D()
# 143 -> Dropout(p=0.1, inplace=False)
# 144 -> Dropout(p=0.1, inplace=False)
# 145 -> LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# 146 -> MLP(
#   (c_fc): Conv1D()
#   (c_proj): Conv1D()
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# 147 -> Conv1D()
# 148 -> Conv1D()
# 149 -> Dropout(p=0.1, inplace=False)
# 150 -> LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# 151 -> Linear(in_features=768, out_features=50257, bias=False)
# 152 -> SequenceSummary(
#   (summary): Linear(in_features=768, out_features=1, bias=True)
#   (activation): Identity()
#   (first_dropout): Dropout(p=0.1, inplace=False)
#   (last_dropout): Identity()
# )
# 153 -> Linear(in_features=768, out_features=1, bias=True)
# 154 -> Identity()
# 155 -> Dropout(p=0.1, inplace=False)
# 156 -> Identity()

# %%
cd /usr/local/lib/python3.6/dist-packages/transformers/
# Out:
# /usr/local/lib/python3.6/dist-packages/transformers

# %%
cd data/
# Out:
# /usr/local/lib/python3.6/dist-packages/transformers/data

# %%
ls
# Out:
# configuration_auto.py
# configuration_bert.py
# configuration_ctrl.py
# configuration_distilbert.py
# configuration_gpt2.py
# configuration_openai.py
# configuration_roberta.py
# configuration_transfo_xl.py
# configuration_utils.py
# configuration_xlm.py
# configuration_xlnet.py
# convert_bert_original_tf_checkpoint_to_pytorch.py
# convert_bert_pytorch_checkpoint_to_original_tf.py
# convert_gpt2_original_tf_checkpoint_to_pytorch.py
# convert_openai_original_tf_checkpoint_to_pytorch.py
# convert_pytorch_checkpoint_to_tf2.py
# convert_roberta_original_pytorch_checkpoint_to_pytorch.py
# convert_transfo_xl_original_tf_checkpoint_to_pytorch.py
# convert_xlm_original_pytorch_checkpoint_to_pytorch.py
# convert_xlnet_original_tf_checkpoint_to_pytorch.py
# data/
# file_utils.py
# __init__.py
# __main__.py
# modeling_auto.py
# modeling_bert.py
# modeling_ctrl.py
# modeling_distilbert.py
# modeling_gpt2.py
# modeling_openai.py
# modeling_roberta.py
# modeling_tf_auto.py
# modeling_tf_bert.py
# modeling_tf_ctrl.py
# modeling_tf_distilbert.py
# modeling_tf_gpt2.py
# modeling_tf_openai.py
# modeling_tf_pytorch_utils.py
# modeling_tf_roberta.py
# modeling_tf_transfo_xl.py
# modeling_tf_transfo_xl_utilities.py
# modeling_tf_utils.py
# modeling_tf_xlm.py
# modeling_tf_xlnet.py
# modeling_transfo_xl.py
# modeling_transfo_xl_utilities.py
# modeling_utils.py
# modeling_xlm.py
# modeling_xlnet.py
# optimization.py
# __pycache__/
# tokenization_auto.py
# tokenization_bert.py
# tokenization_ctrl.py
# tokenization_distilbert.py
# tokenization_gpt2.py
# tokenization_openai.py
# tokenization_roberta.py
# tokenization_transfo_xl.py
# tokenization_utils.py
# tokenization_xlm.py
# tokenization_xlnet.py
# transformers/

# %%
mv transformers/ transformers-git/

# %%
cd transformers-git/
# Out:
# /usr/local/lib/python3.6/dist-packages/transformers/transformers-git

# %%
ls
# Out:
# CONTRIBUTING.md  examples/   MANIFEST.in  requirements-dev.txt  templates/
# docker/          hubconf.py  notebooks/   requirements.txt      transformers/
# docs/            LICENSE     README.md    setup.py

# %%
cd examples/
# Out:
# /usr/local/lib/python3.6/dist-packages/transformers/transformers-git/examples

# %%
# !python run_generation.py \
    --model_type=gpt2 \
    --model_name_or_path=gpt2
# Out:
# 11/04/2019 21:39:35 - INFO - transformers.tokenization_utils -   loading file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-vocab.json from cache at /root/.cache/torch/transformers/f2808208f9bec2320371a9f5f891c184ae0b674ef866b79c58177067d15732dd.1512018be4ba4e8726e41b9145129dc30651ea4fec86aa61f4b9f40bf94eac71
# 11/04/2019 21:39:35 - INFO - transformers.tokenization_utils -   loading file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-merges.txt from cache at /root/.cache/torch/transformers/d629f792e430b3c76a1291bb2766b0a047e36fae0588f9dbc1ae51decdff691b.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda
# 11/04/2019 21:39:35 - INFO - transformers.configuration_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-config.json from cache at /root/.cache/torch/transformers/4be02c5697d91738003fb1685c9872f284166aa32e061576bbe6aaeb95649fcf.085d5f6a8e7812ea05ff0e6ed0645ab2e75d80387ad55c1ad9806ee70d272f80
# 11/04/2019 21:39:35 - INFO - transformers.configuration_utils -   Model config {
#   "attn_pdrop": 0.1,
#   "embd_pdrop": 0.1,
#   "finetuning_task": null,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "num_labels": 1,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pruned_heads": {},
#   "resid_pdrop": 0.1,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "torchscript": false,
#   "use_bfloat16": false,
#   "vocab_size": 50257
# }
#
# 11/04/2019 21:39:36 - INFO - transformers.modeling_utils -   loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-pytorch_model.bin from cache at /root/.cache/torch/transformers/4295d67f022061768f4adc386234dbdb781c814c39662dd1662221c309962c55.778cf36f5c4e5d94c8cd9cefcf2a580c8643570eb327f0d4a1f007fab2acbdf1
# Hello
# 11/04/2019 21:39:45 - INFO - __main__ -   Namespace(device=device(type='cuda'), length=20, model_name_or_path='gpt2', model_type='gpt2', n_gpu=1, no_cuda=False, num_samples=1, padding_text='', prompt='', repetition_penalty=1.0, seed=42, stop_token=None, temperature=1.0, top_k=0, top_p=0.9, xlm_lang='')
# 100% 20/20 [00:00<00:00, 40.71it/s]
#  this gifting came from the same person (and his name is who I came up with "we
# Model prompt >>> What we?
# 100% 20/20 [00:00<00:00, 38.02it/s]
#  - An Apprentice Mists Of Medusa."
#
# This article was updated on July 6 to include
# Model prompt >>>

# %%
export TRAIN_FILE=/path/to/dataset/wiki.train.raw
export TEST_FILE=/path/to/dataset/wiki.test.raw

python run_lm_finetuning.py \
    --output_dir=output \
    --model_type=gpt2 \
    --model_name_or_path=gpt2 \
    --do_train \
    --train_data_file=$TRAIN_FILE \
    --do_eval \
    --eval_data_file=$TEST_FILE
# Out:
#   File "<ipython-input-43-431402a7e9f2>", line 1
#     export TRAIN_FILE=/path/to/dataset/wiki.train.raw
#                     ^
# SyntaxError: invalid syntax
