# %%
# !git clone https://github.com/ilopezfr/gpt-2/
import os
os.chdir('gpt-2')
# !python download_model.py 117M
# !python download_model.py 345M
#!python download_model.py 774M
# !python download_model.py 1558M
# !pip3 install -r requirements.txt

# %%
# !python3 src/generate_unconditional_samples.py

# %%
# !python3 src/generate_unconditional_samples.py --model_name='1558M' --nsamples=2 --top_k=40 --temperature=0.7 | tee samples
# Out:
# WARNING:tensorflow:From src/generate_unconditional_samples.py:54: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-11-07 18:59:50.037676: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-11-07 18:59:50.074958: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-11-07 18:59:50.075577: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2019-11-07 18:59:50.082416: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2019-11-07 18:59:50.228375: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2019-11-07 18:59:50.316678: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2019-11-07 18:59:50.340120: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2019-11-07 18:59:50.519587: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2019-11-07 18:59:50.630957: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2019-11-07 18:59:50.999177: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2019-11-07 18:59:50.999409: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-11-07 18:59:51.000097: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-11-07 18:59:51.000712: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2019-11-07 18:59:51.011641: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-11-07 18:59:51.011875: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x21ab100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2019-11-07 18:59:51.011903: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2019-11-07 18:59:51.151084: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-11-07 18:59:51.151806: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x21ab2c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2019-11-07 18:59:51.151830: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2019-11-07 18:59:51.153040: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-11-07 18:59:51.153593: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2019-11-07 18:59:51.153661: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2019-11-07 18:59:51.153688: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2019-11-07 18:59:51.153710: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2019-11-07 18:59:51.153733: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2019-11-07 18:59:51.153753: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2019-11-07 18:59:51.153786: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2019-11-07 18:59:51.153807: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2019-11-07 18:59:51.153895: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-11-07 18:59:51.154463: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-11-07 18:59:51.155007: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2019-11-07 18:59:51.158060: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2019-11-07 18:59:51.159432: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-11-07 18:59:51.159471: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2019-11-07 18:59:51.159482: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2019-11-07 18:59:51.160726: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-11-07 18:59:51.161393: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-11-07 18:59:51.161969: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2019-11-07 18:59:51.162028: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# WARNING:tensorflow:From src/generate_unconditional_samples.py:57: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:51: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From /content/gpt-2/src/model.py:148: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/gpt-2/src/model.py:152: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/gpt-2/src/model.py:36: The name tf.rsqrt is deprecated. Please use tf.math.rsqrt instead.
#
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:64: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:16: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:67: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.random.categorical` instead.
# WARNING:tensorflow:From src/generate_unconditional_samples.py:66: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# Hello, what is yor name?
# My name is George.
# 2019-11-07 19:00:53.566477: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# soooo
# what
# ======================================== SAMPLE 1 ========================================
# What's the deal with those giant rubber balls that are popping up all over the city?
#
# They're a way to try to catch the city's homeless.
#
# The balls, which are about the size of a tennis ball, come in a variety of colors, but usually black.
#
# They're made from recycled materials, and each one has a "catchphrase" — such as "Turtle Power," "Help Me" or "I'm a Friend."
#
# The balls have been popping up around the city and in other cities, but they're not a new concept.
#
# The city of San Francisco has also been handing out colorful balls, which are about the size of a tennis ball, to try to catch the homeless. (CBS)
#
# The balls are made from recycled materials, and they have a "catchphrase" — such as "Turtle Power," "Help Me" or "I'm a Friend." (CBS)
#
# The balls have been popping up around the city and in other cities, but they're not a new concept.
#
# The city of San Francisco has also been handing out colorful balls, which are about the size of a tennis ball, to try to catch the homeless.
#
# The balls can be found at locations such as City Hall plaza, at the Civic Center Plaza and on the ground in front of City Hall.
#
# "I've seen them in the Mission, in the Castro, in the Tenderloin. I've seen them at St. Anthony's, and at the Mission Police Station," said San Francisco city employee Michael McAlpin.
#
# Each ball is marked with the person's name and the location where they were found, according to McAlpin.
#
# The balls have caught the attention of city officials, who say the balloons are a way to help the homeless and to build community.
#
# "It's a way to say, 'Hey, we're out here, we're present, we care, we want to help you. We want to make the city better,'" said John Coté, San Francisco's director of community services.
#
# McAlpin said they're trying to get more people out of their cars and on the streets.
#
# "We have people sleeping along the streets, we have homeless people sleeping in the middle of the street, we have homeless people sleeping in the middle of the sidewalks," he said.
#
# The balls have attracted the attention of the city's homeless outreach team, called "The Streets of San Francisco," which has been out in force to catch homeless people and hand out the colorful balls.
#
# "It's about having a conversation, and getting people to see there are better things than what they're thinking, and better things than what they're doing," Coté said.
#
# Coté said he hopes the balls will make people think about their own lives and the lives of their friends and families.
#
# "If we just focus on what we do best, that's what we'll do well. We're not going to be homeless, we're not going to be in the streets, we're going to do well," he said.<|endoftext|>A recent study by the European Network Against Racism, the European Anti-Fascists Network and the Anti-Fascist Action Group has found that far-right groups in the UK are becoming more extreme.
#
# The report, called the UK's Radical Right: Extremism and the Radical Right in the UK, looked at the views of 1,000 members of the far-right National Front, the English Defence League and the West Midlands Infidels.
#
# The study found that the far-right had become more extreme in the past five years. In the last year alone they had grown in influence, increasing by 15 per cent in the UK.
#
# The study found a number of radical right groups are trying to "paint a picture of an increasingly radicalised society, one in which a radicalised core is trying to take over".
#
# The report stated: "The key message of this report is that there is a radical right in the UK which is growing in influence and is increasingly militant and intolerant of opposing views."
#
# The report was based on over 800 interviews with members of the far-right groups conducted in 2014 and 2015.
#
# Dr Matthew Goodwin, a University of Kent professor of sociology and co-author of the study, said: "We're not saying that people are being radicalised. What we are saying is that people who are radicalised are becoming more extreme.
#
# "They are a threat to the way the country is going and I think we need to be doing more to confront and counter this threat."
#
# The report also found that the far-right groups are targeting young people.
#
# "Young people are more likely than older Britons to see the far-right as a threat to national security and to feel that the far-right is trying to take over society," said Dr
# ======================================== SAMPLE 2 ========================================
# Bryan Cranston, left, and Vince Vaughn in "Breaking Bad" (AMC)
#
# Breaking Bad has been renewed for a sixth season, as has a new version of "The Office."
#
# Both were announced during the network's upfront presentation on Sunday evening, and both had been widely expected to see a renewal.
#
# The renewal of "Breaking Bad" comes as a surprise given AMC's struggles with the series, which is the network's highest-rated scripted show and has been in its seventh season since its debut in 2010. The show has seen a significant drop in ratings over the past few years, though it has been able to remain in the top 10 of the overall Emmy Awards each year since its 2012 debut.
#
# The renewal of "The Office" comes as a surprise given that the CBS comedy is on a downward slide in its fifth season, but it has been on the air for the past three years.
#
# The renewal of "Breaking Bad" comes after the network also renewed "Better Call Saul" for a sixth season, but the show has not been a ratings success to date.<|endoftext|>The idea of a universal basic income for all Americans is gaining momentum around the world.
#
# In Finland, the government is exploring the idea of a universal guaranteed income for all Americans as a way to replace the current system of welfare and unemployment benefits.
#
# In the United Kingdom, a group of economists are exploring the possibility of a basic income guarantee for all adults.
#
# And in the Netherlands, the Dutch government is considering a pilot program to offer a basic income to all Dutch residents.
#
# "We have to make sure that we have a society that is sustainable and that's where we're heading," says Peter Denholm, professor emeritus at the University of Oregon and author of the book "The Universal Basic Income: A New Way of Life."
#
# Denholm says the basic income could make the U.S. more like other wealthy countries that have experimented with the idea -- like Denmark, Finland and Sweden. He says these countries have all experienced significant drops in poverty and unemployment.
#
# "The reason we haven't seen more of that is because our government has been so focused on austerity measures and cutting back on services," he says.
#
# And the idea of a universal basic income is gaining momentum in the U.S.
#
# Denholm says it's the answer to a major problem facing the U.S. -- how to deal with a growing elderly population.
#
# "If the system is just for the young, then you don't get into the problem of the old," he says.
#
# Denholm says the idea is a way to help people who are currently on the sidelines of the economy.
#
# "It's about getting people into the game who want to be engaged in the economy, and it's also about getting people off the sidelines and getting them back into the workforce, so it's a win-win for everybody," he says.
#
# The idea of a universal basic income is gaining traction in countries around the world.
#
# Denholm says the idea is gaining support among Republicans. His book is being used by the Cato Institute, a libertarian think tank based in Washington, D.C. The institute released a report last year calling for a universal basic income.
#
# "We have to make sure that we have a society that is sustainable and that's where we're heading." - Peter Denholm, professor emeritus at the University of Oregon
#
# Denholm says the U.S. could use a basic income guarantee. In the U.S., he says, the current system of welfare and unemployment benefits is creating a cycle of dependency.
#
# "The problem is that if you are not working to get benefits, you don't get them. If you do get them, they're not enough for you to be able to live on them," he says.
#
# Denholm says a basic income would help address the problem of dependence.
#
# "In a sense, a basic income is a social safety net that helps people have more self-determination, so that they can make more of an individual decision about their life," he says.
#
# Denholm says a universal basic income would be paid to all adults by the government. He says it would replace unemployment and welfare benefits. It also would replace private insurance and Social Security benefits.
#
# Denholm says his idea is not a radical one -- it's just a different way of approaching the problem.
#
# "It's really not radical at all," he says. "It's just another way of looking at a problem."
#
# This story is part of a reporting partnership between NPR and member station WAMU and Kaiser Health News.<|endoftext|>Cannabis use has been associated with a number of psychosocial problems associated with poor mental health, including depression, suicidal behavior, and anxiety. However, the relation between cannabis use and psychosis has not been investigated. The aim of the present study was to examine
